# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/content/mobile_price_classification.csv')

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  int_memory  \
# 0            842          0          2.2         0          1   0           7
# 1           1021          1          0.5         1          0   1          53
# 2            563          1          0.5         1          2   1          41
# 3            615          1          2.5         0          0   0          10
# 4           1821          1          1.2         0         13   1          44
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
# 3    0.8        131        6  ...       1216      1786  2769    16     8
# 4    0.6        141        2  ...       1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.describe()
# Out:
#        battery_power  bluetooth  clock_speed     dual_sim    front_cam  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#                 4G   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   battery_power   2000 non-null   int64
#  1   bluetooth       2000 non-null   int64
#  2   clock_speed     2000 non-null   float64
#  3   dual_sim        2000 non-null   int64
#  4   front_cam       2000 non-null   int64
#  5   4G              2000 non-null   int64
#  6   int_memory      2000 non-null   int64
#  7   m_dep           2000 non-null   float64
#  8   mobile_wt       2000 non-null   int64
#  9   n_cores         2000 non-null   int64
#  10  primary_camera  2000 non-null   int64
#  11  px_height       2000 non-null   int64
#  12  px_width        2000 non-null   int64
#  13  ram             2000 non-null   int64
#  14  sc_h            2000 non-null   int64
#  15  sc_w            2000 non-null   int64
#  16  talk_time       2000 non-null   int64
# ...

# %%
data.isna().sum()
# Out:
# battery_power     0
# bluetooth         0
# clock_speed       0
# dual_sim          0
# front_cam         0
# 4G                0
# int_memory        0
# m_dep             0
# mobile_wt         0
# n_cores           0
# primary_camera    0
# px_height         0
# px_width          0
# ram               0
# sc_h              0
# sc_w              0
# talk_time         0
# three_g           0
# touch_screen      0
# wifi              0
# price_range       0
# dtype: int64

# %%
data['price_range'].nunique()
# Out:
# 4

# %%
np.unique(data['price_range'])
# Out:
# array([0, 1, 2, 3])

# %%
data['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
x = data.drop('price_range',axis = 1)
y = data['price_range']

# %%
#Feature Selection for better results and accuracy
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
selectKBest = SelectKBest(chi2,k=10)

# %%
bestFeatures = selectKBest.fit(x,y)

# %%
bestFeatures.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
x_features = pd.DataFrame(bestFeatures.scores_)
x_columns = pd.DataFrame(x.columns)

# %%
featureScores = pd.concat([x_columns,x_features],axis=1)

# %%
featureScores.columns = ['Features','Score']

# %%
featureScores.sort_values(by='Score',ascending=False)
# Out:
#           Features          Score
# 13             ram  931267.519053
# 11       px_height   17363.569536
# 0    battery_power   14129.866576
# 12        px_width    9810.586750
# 8        mobile_wt      95.972863
# 6       int_memory      89.839124
# 15            sc_w      16.480319
# 16       talk_time      13.236400
# 4        front_cam      10.135166
# 14            sc_h       9.614878
# 10  primary_camera       9.186054
# 9          n_cores       9.097556
# 18    touch_screen       1.928429
# 5               4G       1.521572
# 7            m_dep       0.745820
# 1        bluetooth       0.723232
# 2      clock_speed       0.648366
# 3         dual_sim       0.631011
# 19            wifi       0.422091
# 17         three_g       0.327643

# %%
x = data[['ram','px_height','battery_power','px_width','mobile_wt','int_memory','sc_w','talk_time','front_cam','sc_h']]

# %%
x.head()
# Out:
#     ram  px_height  battery_power  px_width  mobile_wt  int_memory  sc_w  \
# 0  2549         20            842       756        188           7     7
# 1  2631        905           1021      1988        136          53     3
# 2  2603       1263            563      1716        145          41     2
# 3  2769       1216            615      1786        131          10     8
# 4  1411       1208           1821      1212        141          44     2
#
#    talk_time  front_cam  sc_h
# 0         19          1     9
# 1          7          0    17
# 2          9          2    11
# 3         11          0    16
# 4         15         13     8

# %%
x.shape
# Out:
# (2000, 10)

# %%
x.describe()
# Out:
#                ram    px_height  battery_power     px_width    mobile_wt  \
# count  2000.000000  2000.000000    2000.000000  2000.000000  2000.000000
# mean   2124.213000   645.108000    1238.518500  1251.515500   140.249000
# std    1084.732044   443.780811     439.418206   432.199447    35.399655
# min     256.000000     0.000000     501.000000   500.000000    80.000000
# 25%    1207.500000   282.750000     851.750000   874.750000   109.000000
# 50%    2146.500000   564.000000    1226.000000  1247.000000   141.000000
# 75%    3064.500000   947.250000    1615.250000  1633.000000   170.000000
# max    3998.000000  1960.000000    1998.000000  1998.000000   200.000000
#
#         int_memory         sc_w    talk_time    front_cam         sc_h
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     32.046500     5.767000    11.011000     4.309500    12.306500
# std      18.145715     4.356398     5.463955     4.341444     4.213245
# ...

# %%
x = x.values
y = y.values

# %%
# scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
y = y.reshape(-1,1)

# %%
# next converting y labels to one hot encoder
from sklearn.preprocessing import OneHotEncoder
oneHotEncoder = OneHotEncoder()
y = (oneHotEncoder.fit_transform(y)).toarray()

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=101)

# %%
#ANN model
import keras
from keras.models import Sequential
from keras.layers import *

# %%
model = Sequential()
model.add(Dense(8,activation='relu',input_dim = 10))
model.add(Dense(6,activation='relu'))
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 88
#
#  dense_1 (Dense)             (None, 6)                 54
#
#  dense_2 (Dense)             (None, 4)                 28
#
# ...
# Total params: 170 (680.00 Byte)
# Trainable params: 170 (680.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=105,validation_data=(x_test,y_test),batch_size=64)
# Out:
# Epoch 1/105
# 25/25 [==============================] - 1s 14ms/step - loss: 1.4584 - accuracy: 0.2469 - val_loss: 1.3964 - val_accuracy: 0.3050
# Epoch 2/105
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4210 - accuracy: 0.2694 - val_loss: 1.3726 - val_accuracy: 0.3200
# Epoch 3/105
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3933 - accuracy: 0.2869 - val_loss: 1.3547 - val_accuracy: 0.3250
# Epoch 4/105
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3708 - accuracy: 0.3144 - val_loss: 1.3391 - val_accuracy: 0.3300
# Epoch 5/105
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3487 - accuracy: 0.3456 - val_loss: 1.3212 - val_accuracy: 0.3475
# Epoch 6/105
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3249 - accuracy: 0.3756 - val_loss: 1.3014 - val_accuracy: 0.3900
# Epoch 7/105
# ...

# %%
y_pred = model.predict(x_test)
# inverse one hot encoding for x_test
pred = []
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))

# inverse encoding for y_test labels

test = []
for i in range(len(y_test)):
    test.append(np.argmax(y_test[i]))
# Out:
# 13/13 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(pred,test)
print("Accuracy  : " , str(acc*100))
# Out:
# Accuracy  :  96.5

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Features','Price_Weight'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Features','Price_Weight'],loc='upper left')
plt.show()
